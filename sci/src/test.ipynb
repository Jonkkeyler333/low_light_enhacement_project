# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls drive/MyDrive/procesamiento_imagenes
# Out:
#  2221551_4_EcualizacionHistograma.ipynb
#  2221551_6_Shared_Transformaciones_Vecindario_NoLineales.ipynb
#  3_Transformaciones_Pixel.ipynb
# 'Copia de 5_Shared_Convolution.ipynb'
#  LOLdataset.zip
#  Shared_Examen1_UnsharpMasking.ipynb
#  Taller1_Demosaicking

# %%
# !pwd
# Out:
# /content

# %%
! ls
# Out:
# data  drive  sample_data

# %%
# !unzip -q /content/drive/MyDrive/procesamiento_imagenes/LOLdataset.zip -d /content/data

# %%
import PIL.Image as Image
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

path = "/content/data/our485/low/10.png"

image = Image.open(path)
image_array = np.array(image)
plt.imshow(image_array)
plt.axis('off')
plt.grid(False)
plt.show()

# %%
plt.hist(image_array.ravel(), bins=256, range=(0, 255), color='blue', alpha=0.5)
plt.show()

# %%
# import os

# repo_url = "https://github.com/Jonkkeyler333/low_light_enhacement_project.git"
# repo_dir = "/content/low_light_enhacement_project"

# if not os.path.exists(repo_dir):
#     !git clone {repo_url} {repo_dir}
# else:
#     %cd {repo_dir}
#     !git pull

# %cd /content/low_light_enhacement_project/sci
# !python -m src.train
# Out:
# /content/low_light_enhacement_project/sci
# hello world
